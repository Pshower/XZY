# %%
import pandas as pd
import numpy as np
import time
from multiprocessing.dummy import Pool as ThreadPool
from q_tools.data import *
import talib
from math import atan

# %%
df=total_data(sort_type='code')
df
# Out:
#               code   open  close   high    low     volume         value  \
# date
# 2011-01-04  600000   2.24   2.34   2.38   2.17  1043015.0  1.307175e+09
# 2011-01-05  600000   2.39   2.39   2.50   2.35  1070142.0  1.367751e+09
# 2011-01-06  600000   2.40   2.37   2.49   2.33   639541.0  8.144517e+08
# 2011-01-07  600000   2.38   2.67   2.82   2.32  2787976.0  3.673753e+09
# 2011-01-10  600000   2.61   2.59   2.73   2.51  1280075.0  1.679802e+09
# ...            ...    ...    ...    ...    ...        ...           ...
# 2024-05-27  300999  31.14  31.04  31.18  30.66    39192.0  1.211401e+08
# 2024-05-28  300999  31.00  30.75  31.05  30.66    36548.0  1.125671e+08
# 2024-05-29  300999  30.71  30.60  30.91  30.50    34766.0  1.067375e+08
# 2024-05-30  300999  30.45  30.55  30.75  30.35    32664.0  9.963866e+07
# 2024-05-31  300999  30.66  30.08  30.77  30.08    55292.0  1.676691e+08
#
#             amplitude    A-D  range  turnover
# date
# ...

# %%
df[df['code']=='600000']['ma5'] = talib.MA(df[df['code']=='600000']['close'],timeperiod=5)
# Out:
# C:\Users\Shower\AppData\Local\Temp\ipykernel_24468\1328736342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['code']=='600000']['ma5'] = talib.MA(df[df['code']=='600000']['close'],timeperiod=5)

# %%
df[df['code']=='600000']
# Out:
#               code  open  close  high   low     volume         value  \
# date
# 2011-01-04  600000  2.24   2.34  2.38  2.17  1043015.0  1.307175e+09
# 2011-01-05  600000  2.39   2.39  2.50  2.35  1070142.0  1.367751e+09
# 2011-01-06  600000  2.40   2.37  2.49  2.33   639541.0  8.144517e+08
# 2011-01-07  600000  2.38   2.67  2.82  2.32  2787976.0  3.673753e+09
# 2011-01-10  600000  2.61   2.59  2.73  2.51  1280075.0  1.679802e+09
# ...            ...   ...    ...   ...   ...        ...           ...
# 2024-05-27  600000  8.45   8.54  8.56  8.43   528587.0  4.499326e+08
# 2024-05-28  600000  8.58   8.54  8.64  8.51   400473.0  3.429045e+08
# 2024-05-29  600000  8.53   8.49  8.59  8.45   408024.0  3.472902e+08
# 2024-05-30  600000  8.47   8.40  8.55  8.36   567016.0  4.791462e+08
# 2024-05-31  600000  8.45   8.34  8.45  8.31   537973.0  4.496890e+08
#
#             amplitude    A-D  range  turnover
# date
# 2011-01-04       9.46   5.41   0.12      0.91
# ...

# %%
tmp=talib.MA(df[df['code']=='600000']['code']['close'],timeperiod=5)
tmp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\ProgramFiles\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ...

# %%
listS=get_index_codes()
len(listS)

# %%
len(df)

# %%
len(df)/len(listS)

# %%
sum(df['code']=='000001')
