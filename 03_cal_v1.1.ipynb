# %%
import pandas as pd
import numpy as np
import time
from multiprocessing.dummy import Pool as ThreadPool
from q_tools.data import *
from q_tools.cal import *
import talib
from math import atan

# %%
listS=get_index_codes()

# %%
data=get_data(listS[0])

# %%
data
# Out:
#               code  open  close  high   low     volume         value  \
# date
# 2011-01-04  600000  2.24   2.34  2.38  2.17  1043015.0  1.307175e+09
# 2011-01-05  600000  2.39   2.39  2.50  2.35  1070142.0  1.367751e+09
# 2011-01-06  600000  2.40   2.37  2.49  2.33   639541.0  8.144517e+08
# 2011-01-07  600000  2.38   2.67  2.82  2.32  2787976.0  3.673753e+09
# 2011-01-10  600000  2.61   2.59  2.73  2.51  1280075.0  1.679802e+09
# ...            ...   ...    ...   ...   ...        ...           ...
# 2024-05-27  600000  8.45   8.54  8.56  8.43   528587.0  4.499326e+08
# 2024-05-28  600000  8.58   8.54  8.64  8.51   400473.0  3.429045e+08
# 2024-05-29  600000  8.53   8.49  8.59  8.45   408024.0  3.472902e+08
# 2024-05-30  600000  8.47   8.40  8.55  8.36   567016.0  4.791462e+08
# 2024-05-31  600000  8.45   8.34  8.45  8.31   537973.0  4.496890e+08
#
#             amplitude    A-D  range  turnover
# date
# 2011-01-04       9.46   5.41   0.12      0.91
# ...

# %%
fac=process_(data)
fac
# Out:
#               code  open  close  high   low     volume         value  \
# date
# 2011-01-04  600000  2.24   2.34  2.38  2.17  1043015.0  1.307175e+09
# 2011-01-05  600000  2.39   2.39  2.50  2.35  1070142.0  1.367751e+09
# 2011-01-06  600000  2.40   2.37  2.49  2.33   639541.0  8.144517e+08
# 2011-01-07  600000  2.38   2.67  2.82  2.32  2787976.0  3.673753e+09
# 2011-01-10  600000  2.61   2.59  2.73  2.51  1280075.0  1.679802e+09
# ...            ...   ...    ...   ...   ...        ...           ...
# 2024-05-27  600000  8.45   8.54  8.56  8.43   528587.0  4.499326e+08
# 2024-05-28  600000  8.58   8.54  8.64  8.51   400473.0  3.429045e+08
# 2024-05-29  600000  8.53   8.49  8.59  8.45   408024.0  3.472902e+08
# 2024-05-30  600000  8.47   8.40  8.55  8.36   567016.0  4.791462e+08
# 2024-05-31  600000  8.45   8.34  8.45  8.31   537973.0  4.496890e+08
#
#             amplitude    A-D  range  ...      k1_1      k1_2        hc  \
# date                                 ...
# ...

# %%
factor_name = [ 'target2','factor0','factor1','factor2','factor3','return1', 'return3', 'return5', 'bias5', 'bias10', 'bias21', 'bias55',
        'bias5_', 'bias10_', 'bias21_', 'bias55_', 'trend5','increase5','increase_vol5',
       'trend21', 'high5', 'high10', 'high21', 'k1', 'k1_1', 'k1_2', 'hc',
       'return1_', 'return3_', 'return5_','vol21_', 'vol21_1', 'vol21_2',
       'vol21_3']

# %%
pricing=pd.DataFrame(fac['close'])
pricing.columns=[listS[0]]

# %%
listS[0]
# Out:
# '600000'

# %%
pricing
# Out:
#             600000
# date
# 2011-01-04    2.34
# 2011-01-05    2.39
# 2011-01-06    2.37
# 2011-01-07    2.67
# 2011-01-10    2.59
# ...            ...
# 2024-05-27    8.54
# 2024-05-28    8.54
# 2024-05-29    8.49
# 2024-05-30    8.40
# 2024-05-31    8.34
#
# [3257 rows x 1 columns]

# %%
periods=data_line()
periods=pd.to_datetime(periods.index)
days = pd.Index(periods)
idx_df = days.to_frame()
freq = 'ME'
if freq[-1] == 'E':
    day_range = idx_df.resample(freq[0]).last()
else:
    day_range = idx_df.resample(freq[0]).first()

day_range = day_range['date'].dt.date
periods=day_range.dropna().values.tolist()
periods
# Out:
# [datetime.date(2011, 1, 31),
#  datetime.date(2011, 2, 28),
#  datetime.date(2011, 3, 31),
#  datetime.date(2011, 4, 29),
#  datetime.date(2011, 5, 31),
#  datetime.date(2011, 6, 30),
#  datetime.date(2011, 7, 29),
#  datetime.date(2011, 8, 31),
#  datetime.date(2011, 9, 30),
#  datetime.date(2011, 10, 31),
#  datetime.date(2011, 11, 30),
#  datetime.date(2011, 12, 30),
#  datetime.date(2012, 1, 31),
#  datetime.date(2012, 2, 29),
#  datetime.date(2012, 3, 30),
#  datetime.date(2012, 4, 27),
#  datetime.date(2012, 5, 31),
#  datetime.date(2012, 6, 29),
#  datetime.date(2012, 7, 31),
#  datetime.date(2012, 8, 31),
#  datetime.date(2012, 9, 28),
#  datetime.date(2012, 10, 31),
#  datetime.date(2012, 11, 30),
#  datetime.date(2012, 12, 31),
#  datetime.date(2013, 1, 31),
#  datetime.date(2013, 2, 28),
#  datetime.date(2013, 3, 29),
#  datetime.date(2013, 4, 26),
#  datetime.date(2013, 5, 31),
#  datetime.date(2013, 6, 28),
#  datetime.date(2013, 7, 31),
#  datetime.date(2013, 8, 30),
# ...

# %%
get_close_price

# %%
data.loc[str(periods[0]),'close']
# Out:
# 2.4

# %%
# 获取因子回测数据

res_dic = {}
for name in factor_name:

    res = get_factor_returns(fac, name, 0.4)
    res.get_calc(pricing)
    res.long_short(5, 1)
    res_dic[name] = res
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 7
#       4 for name in factor_name:
#       6     res = get_factor_returns(fac, name, 0.4)
# ----> 7     res.get_calc(pricing)
#       8     res.long_short(5, 1)
#       9     res_dic[name] = res
#
# File ~\Jupyter File\02_ss量化投资课\课程项目\q_tools\cal.py:90, in get_factor_returns.get_calc(self, pricing, periods, quantiles)
#      87 def get_calc(self, pricing: pd.DataFrame, periods: Tuple = (1,), quantiles: int = 5) -> pd.DataFrame:
#      89     factor_ser: pd.Series = self.factors[self.factor_name]
# ---> 90     preprocessing_factor = al.utils.get_clean_factor_and_forward_returns(factor_ser,
#      91                                                                          pricing,
#      92                                                                          periods=periods,
# ...
